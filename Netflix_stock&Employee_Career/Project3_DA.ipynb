# %% [markdown]
# #NETFLIX STOCK ANALYSIS PROJECT

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df =pd.read_csv("NFLX.csv")

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
sns.set(rc= {'figure.figsize':(10,5)})

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
sns.lineplot(x = df.index, y = df['Volume'], label = 'Volume')
plt.show()

# %%
df.plot(y = ['High','Close','Open'], title ="Netflix Stock Price")
plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3, figsize= (15,10))
df.groupby(df.index.day).mean().plot(y = 'Volume', ax=ax1, xlabel = 'Day')
df.groupby(df.index.month).mean().plot(y = 'Volume', ax = ax2, xlabel = "Months")
df.groupby(df.index.year).mean().plot(y='Volume',ax = ax3, xlabel = 'Year')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# #Days with highest Stock Price

# %%
a = df.sort_values(by = 'High', ascending = False).head(5)

# %%
a['High']
# Out:
# Date
# 2021-11-17    700.989990
# 2021-11-19    694.159973
# 2021-11-18    691.739990
# 2021-10-29    690.969971
# 2021-11-01    689.969971
# Name: High, dtype: float64

# %%
b = df.sort_values(by='Low',ascending=True).head(5)
b['Low']
# Out:
# Date
# 2002-10-10    0.346429
# 2002-10-09    0.347143
# 2002-10-07    0.382143
# 2002-10-08    0.390714
# 2002-10-16    0.442857
# Name: Low, dtype: float64

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2, sharex = True, figsize = (12,5))
fig.suptitle('High and Low Values Stock per period of time', fontsize=18)
sns.lineplot(ax = axes[0], y = df['High'], x = df.index, color = 'green')
sns.lineplot(ax = axes[1], y = df['Low'], x = df.index, color = 'red')
# Out:
# <Axes: xlabel='Date', ylabel='Low'>

# %% [markdown]
# #EMPLOYEE CAREER SURVEY ANALYSIS

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
data = pd.read_csv("Your Career Aspirations of GenZ.csv")

# %%
data.head()
# Out:
#   Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                 India                            273005        Male
# 1                 India                            851129        Male
# 2                 India                            123106      Female
# 3                 India                            834003        Male
# 4                 India                            301019      Female
#
#   Which of the below factors influence the most about your career aspirations ?  \
# 0       People who have changed the world for better
# 1       People who have changed the world for better
# 2                         Social Media like LinkedIn
# 3      People from my circle, but not family members
# 4             Influencers who had successful careers
#
#   Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.  \
# 0                       Yes, I will earn and do that
# ...

# %%
data.columns
# Out:
# Index(['Your Current Country.', 'Your Current Zip Code / Pin Code',
#        'Your Gender',
#        'Which of the below factors influence the most about your career aspirations ?',
#        'Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.',
#        'How likely is that you will work for one employer for 3 years or more ?',
#        'Would you work for a company whose mission is not clearly defined and publicly posted.',
#        'How likely would you work for a company whose mission is misaligned with their public actions or even their product ?',
#        'How likely would you work for a company whose mission is not bringing social impact ?',
#        'What is the most preferred working environment for you.',
#        'Which of the below Employers would you work with.',
#        'Which type of learning environment that you are most likely to work in ?',
# ...

# %%
country = data["Your Current Country."].value_counts()
print(country)
# Out:
# India                       231
# Germany                       2
# United Arab Emirates          1
# United States of America      1
# Name: Your Current Country., dtype: int64

# %%
label = country.index
label
# Out:
# Index(['India', 'Germany', 'United Arab Emirates', 'United States of America'], dtype='object')

# %%
counts = country.values
counts
# Out:
# array([231,   2,   1,   1])

# %%
colors = ['red','lightgreen']
from plotly import graph_objects as go
fig = go.Figure(data=[go.Pie(labels=label, values=counts)])
fig.update_layout(title_text="Current Country")
fig.update_traces(hoverinfo='label+value',textinfo= 'percent', textfont_size = 30,marker = dict(colors = colors, line = dict(color = 'black', width= 3)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Factor influencing career aspiration

# %%
data.head()
# Out:
#   Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                 India                            273005        Male
# 1                 India                            851129        Male
# 2                 India                            123106      Female
# 3                 India                            834003        Male
# 4                 India                            301019      Female
#
#   Which of the below factors influence the most about your career aspirations ?  \
# 0       People who have changed the world for better
# 1       People who have changed the world for better
# 2                         Social Media like LinkedIn
# 3      People from my circle, but not family members
# 4             Influencers who had successful careers
#
#   Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.  \
# 0                       Yes, I will earn and do that
# ...

# %%
question1 = "Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it."
question1 = data[question1].value_counts()
label = question1.index
counts = question1.values
color = ['orange','black']
fig = go.Figure(data=[go.Pie(labels=label, values=counts, marker=dict(colors=color, line=dict(color='black', width=3)))])
fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=30)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
question2 = "Which of the below factors influence the most about your career aspirations ?"
question2 = data[question2].value_counts()
label = question2.index
counts = question2.values
color = ['red','green']
fig = go.Figure(data=[go.Pie(labels=label, values=counts, marker=dict(colors=color, line=dict(color='black', width=3)))])
fig.update_layout(title_text='Factor influencing career aspirations')
fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=30)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.head()
# Out:
#   Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                 India                            273005        Male
# 1                 India                            851129        Male
# 2                 India                            123106      Female
# 3                 India                            834003        Male
# 4                 India                            301019      Female
#
#   Which of the below factors influence the most about your career aspirations ?  \
# 0       People who have changed the world for better
# 1       People who have changed the world for better
# 2                         Social Media like LinkedIn
# 3      People from my circle, but not family members
# 4             Influencers who had successful careers
#
#   Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.  \
# 0                       Yes, I will earn and do that
# ...

# %%
question3 = "How likely is that you will work for one employer for 3 years or more ?"
question3 = data[question3].value_counts()
label = question3.index
counts = question3.values
color = ['aqua','red']
fig = go.Figure(data=[go.Pie(labels=label, values=counts, marker=dict(colors=color, line=dict(color='black', width=3)))])
fig.update_layout(title_text='How likely is that you will work in a company?')
fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=30)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
question4 = "What is the most preferred working environment for you."
question4 = data[question4].value_counts()
label = question4.index
count = question4.values
color = ['yellow','purple']
fig = go.Figure(data=[go.Pie(labels=label, values=counts, marker=dict(colors=color, line=dict(color='black', width=3)))])
fig.update_layout(title_text='Where do they like to work?')
fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=30)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
